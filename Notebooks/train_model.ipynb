# %%
import pandas as pd
print(pd.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 print(pd.__version__)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
import joblib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import pandas as pd
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.preprocessing import LabelEncoder
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Selected symptoms and diseases
symptoms = [
    'stomach_pain', 'vomiting', 'fatigue', 'anxiety', 'weight_loss',
    'restlessness', 'lethargy', 'cough', 'high_fever', 'breathlessness',
    'loss_of_appetite', 'mild_fever', 'malaise', 'chest_pain',
    'fast_heart_rate', 'obesity', 'swollen_extremeties',
    'history_of_alcohol_consumption', 'palpitations'
]

diseases = [
    'Diabetes', 'Bronchial Asthma', 'Hypertension',
    'hepatitis B', 'Hepatitis C', 'Alcoholic hepatitis',
    'Tuberculosis', 'Common Cold', 'Pneumonia',
    'Heart attack', 'Hypothyroidism', 'Hyperthyroidism'
]

# %%
# Load pre-split train and test datasets
train_df = pd.read_csv('C:/Users/DELL/Downloads/Filtered_Training_data.csv')
test_df = pd.read_csv('C:/Users/DELL/Downloads/Filtered_Testing_data.csv')

# Keep only selected symptoms and diseases
train_df = train_df[symptoms + ['prognosis']]
train_df = train_df[train_df['prognosis'].isin(diseases)]

test_df = test_df[symptoms + ['prognosis']]
test_df = test_df[test_df['prognosis'].isin(diseases)]

# Features and labels
X_train = train_df[symptoms]
y_train = train_df['prognosis']

X_test = test_df[symptoms]
y_test = test_df['prognosis']

# %%
# Encode target labels
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)  # use same encoder

# Train XGBoost classifier
model = XGBClassifier(eval_metric='logloss')
xgb.fit(X_train, y_train_encoded)

# Evaluate accuracy
y_pred = xgb.predict(X_test)
acc = accuracy_score(y_test_encoded, y_pred)
print("XGBoost Accuracy:", acc)
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [09:25:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost Accuracy: 1.0

# %%
import os
import joblib

# Create folder inside current working directory
os.makedirs('artifacts', exist_ok=True)

# Save file
joblib.dump({'pipeline': pipeline, 'label_encoder': le}, 'artifacts/pipeline.joblib')

print("Model saved successfully!")
# Out:
# Model saved successfully!
